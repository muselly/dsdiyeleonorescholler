# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
os.chdir('/Users/muselly/Documents/ENS/2019-S1/DataCamp/dsdiyeleonorescholler')

# %%
#import arousal ratings as panda data frame
arousal_df = pd.read_csv('./annotations/annotations-averaged-per-song/dynamic(per-second-annotations)/arousal.csv',index_col = 0)

# %%
arousal_df.head()
# Out:
#          sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# song_id
# 2             -0.109386       -0.114942       -0.116413       -0.118613
# 3             -0.110846       -0.123973       -0.131103       -0.135956
# 4              0.222327        0.179446        0.178388        0.184056
# 5             -0.255613       -0.251579       -0.251958       -0.251124
# 7              0.464234        0.460789        0.460991        0.461046
#
#          sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# song_id
# 2             -0.126457       -0.133199       -0.136856       -0.144713
# 3             -0.140775       -0.144664       -0.163118       -0.165218
# 4              0.176042        0.178720        0.176345        0.175793
# 5             -0.250763       -0.251957       -0.251957       -0.251957
# 7              0.457240        0.465702        0.471809        0.469918
#
#          sample_19000ms  sample_19500ms  ...  sample_622000ms  \
# ...

# %%
#describe arousal ratings as they are... 
arousal_desc1 = arousal_df.describe()
arousal_desc1
#this is not very meaningul since the stats are computed across songs and within time samples!
# Out:
#        sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# count     1802.000000     1802.000000     1802.000000     1802.000000
# mean         0.123961        0.124999        0.125694        0.126370
# std          0.266756        0.267682        0.268578        0.269261
# min         -0.654305       -0.654348       -0.655628       -0.663082
# 25%         -0.071864       -0.070000       -0.072250       -0.072093
# 50%          0.139000        0.140830        0.144438        0.144235
# 75%          0.341000        0.341581        0.343351        0.344000
# max          0.678000        0.687000        0.688000        0.696000
#
#        sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# count     1802.000000     1802.000000     1802.000000     1802.000000
# mean         0.126515        0.126578        0.126825        0.127375
# std          0.269770        0.270248        0.270959        0.272065
# ...

# %%
plt.plot(arousal_desc1.loc["mean"])
plt.title("Evolution of mean arousal through time")
plt.xlabel("500ms samples")
plt.ylabel("Arousal rating")
plt.xticks(list(range(0,len(arousal_desc1.loc["mean"]),100)))
plt.yticks([-1,0,1])
plt.show()

# %%
#we therefore have to transpose the data frame to make something out of its decription
arousal_df_t = arousal_df.transpose()
arousal_df_t.head()
# we now know that there are 1802 songs
# Out:
# song_id             2         3         4         5         7         8     \
# sample_15000ms -0.109386 -0.110846  0.222327 -0.255613  0.464234 -0.138132
# sample_15500ms -0.114942 -0.123973  0.179446 -0.251579  0.460789 -0.136934
# sample_16000ms -0.116413 -0.131103  0.178388 -0.251958  0.460991 -0.140469
# sample_16500ms -0.118613 -0.135956  0.184056 -0.251124  0.461046 -0.138988
# sample_17000ms -0.126457 -0.140775  0.176042 -0.250763  0.457240 -0.138146
#
# song_id             10        12        13        17    ...   2049   2050  \
# sample_15000ms -0.129007  0.222143 -0.342129  0.015965  ... -0.282 -0.300
# sample_15500ms -0.132931  0.224873 -0.346549  0.017168  ... -0.282 -0.306
# sample_16000ms -0.138653  0.230734 -0.347545  0.017347  ... -0.282 -0.312
# sample_16500ms -0.139502  0.231653 -0.349167  0.017458  ... -0.278 -0.308
# sample_17000ms -0.142657  0.233457 -0.346890  0.017344  ... -0.284 -0.306
#
# song_id          2051   2052   2053   2054   2055   2056      2057  \
# ...

# %%
arousal_desc = arousal_df_t.describe()
arousal_desc
#this is more meaningful stats (each column represents one song)
# Out:
# song_id       2          3          4          5          7          8     \
# count    60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean     -0.197517  -0.193187   0.243072  -0.236207   0.376292  -0.131506
# std       0.060047   0.042909   0.056383   0.009459   0.054167   0.015641
# min      -0.272033  -0.265931   0.164226  -0.255613   0.324213  -0.167053
# 25%      -0.261240  -0.236734   0.177582  -0.241087   0.332451  -0.140776
# 50%      -0.164383  -0.173634   0.261933  -0.235395   0.344691  -0.136239
# 75%      -0.143381  -0.164190   0.297639  -0.228914   0.399537  -0.118873
# max      -0.109386  -0.110846   0.315198  -0.220232   0.477970  -0.103533
#
# song_id       10         12         13         17    ...        2049  \
# count    60.000000  60.000000  60.000000  60.000000  ...  537.000000
# mean     -0.171351   0.285944  -0.328970   0.031282  ...   -0.183378
# std       0.016123   0.033087   0.016052   0.034271  ...    0.078422
# ...

# %%
arousal_desc = arousal_desc.transpose()
arousal_desc.head()
#now the columns represent the stats and each line represents a song
# Out:
#          count      mean       std       min       25%       50%       75%  \
# song_id
# 2         60.0 -0.197517  0.060047 -0.272033 -0.261240 -0.164383 -0.143381
# 3         60.0 -0.193187  0.042909 -0.265931 -0.236734 -0.173634 -0.164190
# 4         60.0  0.243072  0.056383  0.164226  0.177582  0.261933  0.297639
# 5         60.0 -0.236207  0.009459 -0.255613 -0.241087 -0.235395 -0.228914
# 7         60.0  0.376292  0.054167  0.324213  0.332451  0.344691  0.399537
#
#               max
# song_id
# 2       -0.109386
# 3       -0.110846
# 4        0.315198
# 5       -0.220232
# 7        0.477970

# %%
#example using query 
arousal_df.query('song_id>100').query('sample_150000ms<0')
# Out:
#          sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# song_id
# 2005           0.326000           0.278           0.294        0.296000
# 2006          -0.256000          -0.266          -0.270       -0.268000
# 2011          -0.274000          -0.272          -0.270       -0.270000
# 2012          -0.358333          -0.355          -0.345       -0.316667
# 2014          -0.272000          -0.198          -0.186       -0.190000
# 2023          -0.262000          -0.224          -0.226       -0.216000
# 2024          -0.148000          -0.148          -0.148       -0.148000
# 2025          -0.172000          -0.170          -0.166       -0.204000
# 2038          -0.226000          -0.222          -0.228       -0.216000
# 2039          -0.222000          -0.226          -0.216       -0.222000
# 2043          -0.082000          -0.092          -0.086       -0.088000
# 2048          -0.262000          -0.272          -0.296       -0.306000
# ...

# %%
#Plotting arousal ratings for song 2

plt.plot(arousal_df.iloc[0])
plt.xlabel("500ms samples")
plt.ylabel("Arousal rating")
plt.xticks(list(range(0,61,20)))
plt.yticks([-1,0,1])
plt.show()

# %%
list(range(0,60,10))
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
arousal_df.query('song_id == 500')
# Out:
#          sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# song_id
# 500            0.352421        0.352826        0.354349        0.353978
#
#          sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# song_id
# 500            0.353695        0.353695        0.351401        0.348753
#
#          sample_19000ms  sample_19500ms  ...  sample_622000ms  \
# song_id                                  ...
# 500            0.349897        0.350218  ...              NaN
#
#          sample_622500ms  sample_623000ms  sample_623500ms  sample_624000ms  \
# song_id
# 500                  NaN              NaN              NaN              NaN
#
#          sample_624500ms  sample_625000ms  sample_625500ms  sample_626000ms  \
# song_id
# 500                  NaN              NaN              NaN              NaN
#
#          sample_626500ms
# song_id
# 500                  NaN
#
# [1 rows x 1224 columns]

# %%
#Plotting arousal ratings for song 649

#plt.plot(arousal_df.query('song_id == 500')) This doesn't work 
plt.plot(arousal_df.iloc[500])
plt.xlabel("500ms samples")
plt.ylabel("Arousal rating")
plt.xticks(list(range(0,61,20)))
plt.yticks([-1,0,1])
plt.show()

# %%
type(arousal_df["sample_15000ms"])
# Out:
# pandas.core.series.Series

# %%
type(arousal_df[["sample_15000ms"]])
# Out:
# pandas.core.frame.DataFrame

# %%
arousal_desc.query('mean<0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# //anaconda3/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# //anaconda3/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'mean'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#extract mean arousal rating for all songs 
np_arousal_desc = np.array(arousal_desc.iloc[1])
np.mean(np_arousal_desc)
# Out:
# 0.13734570384915515

# %%
# One can see that there are songs with 60 500ms samples (30 sec out of a 45 sec musical extract),
#and others that are longer (full songs)
#lets create a data frame with only songs of 60 data points
#arousal_df_testSet 
trainSongs_desc = arousal_desc.query('count == 60')
trainSongs_desc.head()
#there are 1744 songs that correspond to this
# Out:
#          count      mean       std       min       25%       50%       75%  \
# song_id
# 2         60.0 -0.197517  0.060047 -0.272033 -0.261240 -0.164383 -0.143381
# 3         60.0 -0.193187  0.042909 -0.265931 -0.236734 -0.173634 -0.164190
# 4         60.0  0.243072  0.056383  0.164226  0.177582  0.261933  0.297639
# 5         60.0 -0.236207  0.009459 -0.255613 -0.241087 -0.235395 -0.228914
# 7         60.0  0.376292  0.054167  0.324213  0.332451  0.344691  0.399537
#
#               max
# song_id
# 2       -0.109386
# 3       -0.110846
# 4        0.315198
# 5       -0.220232
# 7        0.477970

# %%
trainSongs_desc.iloc[0,0]
# Out:
# 60.0

# %%
#scatterplot of the average rating per song 
plt.scatter(list(range(1744)), trainSongs_desc['mean'], s=1)
plt.show()

# %%
plt.hist(trainSongs_desc['mean'], 50)
# Out:
# (array([ 2.,  2.,  3.,  8.,  3.,  4.,  7., 11., 11., 14., 15., 19., 16.,
#         24., 32., 36., 40., 38., 42., 51., 53., 51., 48., 66., 57., 43.,
#         54., 57., 47., 66., 42., 62., 54., 64., 69., 56., 62., 70., 66.,
#         58., 58., 55., 25., 31., 21., 12., 10.,  6.,  1.,  2.]),
#  array([-0.67303447, -0.64453311, -0.61603175, -0.5875304 , -0.55902904,
#         -0.53052769, -0.50202633, -0.47352497, -0.44502362, -0.41652226,
#         -0.38802091, -0.35951955, -0.33101819, -0.30251684, -0.27401548,
#         -0.24551413, -0.21701277, -0.18851141, -0.16001006, -0.1315087 ,
#         -0.10300735, -0.07450599, -0.04600463, -0.01750328,  0.01099808,
#          0.03949943,  0.06800079,  0.09650215,  0.1250035 ,  0.15350486,
#          0.18200621,  0.21050757,  0.23900893,  0.26751028,  0.29601164,
#          0.32451299,  0.35301435,  0.38151571,  0.41001706,  0.43851842,
#          0.46701977,  0.49552113,  0.52402249,  0.55252384,  0.5810252 ,
# ...

# %%
#make a list of the song_ids that correspond to the 30sec songs 
trainSongs_ids = list([])
for index in range(len(trainSongs_desc)):
    trainSongs_ids.append(trainSongs_desc.iloc[index].name)
    
#and extract them from the original data frame
trainSongs_df = arousal_df.loc[trainSongs_ids]
trainSongs_df.head()
# Out:
#          sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# song_id
# 2             -0.109386       -0.114942       -0.116413       -0.118613
# 3             -0.110846       -0.123973       -0.131103       -0.135956
# 4              0.222327        0.179446        0.178388        0.184056
# 5             -0.255613       -0.251579       -0.251958       -0.251124
# 7              0.464234        0.460789        0.460991        0.461046
#
#          sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# song_id
# 2             -0.126457       -0.133199       -0.136856       -0.144713
# 3             -0.140775       -0.144664       -0.163118       -0.165218
# 4              0.176042        0.178720        0.176345        0.175793
# 5             -0.250763       -0.251957       -0.251957       -0.251957
# 7              0.457240        0.465702        0.471809        0.469918
#
#          sample_19000ms  sample_19500ms  ...  sample_622000ms  \
# ...

# %%
plt.hist(trainSongs_df.query('song_id == 2'))
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# //anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([24.,  3.,  0.,  1.,  0.,  0.,  3., 14., 11.,  4.]),
#  array([-0.2720328 , -0.25576812, -0.23950344, -0.22323876, -0.20697408,
#         -0.1907094 , -0.17444472, -0.15818004, -0.14191536, -0.12565068,
#         -0.109386  ]),
#  <a list of 10 Patch objects>)

# %%
range(len(trainSongs_desc))
# Out:
# range(0, 1744)
